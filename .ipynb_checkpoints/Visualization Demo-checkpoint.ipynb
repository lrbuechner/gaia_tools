# %% [markdown]
# # Examples

# %%
from gaia_tools import viz, query, demo_data
# Out:
# Created TAP+ (v1.2.1) - Connection:
# 	Host: gea.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443
# Created TAP+ (v1.2.1) - Connection:
# 	Host: geadata.esac.esa.int
# 	Use HTTPS: False
# 	Port: 80
# 	SSL Port: 443

# %% [markdown]
# ### Inline ADQL Query
# Querying all stars within 200 parsecs

# %%
sql = "SELECT gaia.source_id, gaia.ra, gaia.ra_error, gaia.dec,gaia.dec_error, \
            gaia.pmra, gaia.pmra_error, gaia.pmdec, gaia.pmdec_error, \
            gaia.radial_velocity, gaia.radial_velocity_error, gaia.parallax, \
            gaia.parallax_error, gaia.phot_g_mean_mag, \
            gaia.phot_bp_mean_mag, gaia.phot_rp_mean_mag \
            \
            FROM gaiadr2.gaia_source as gaia \
            \
            WHERE gaia.parallax >= 5 and (gaia.parallax_error/gaia.parallax) < .2 \
            and gaia.pmra_error < 1.5 and gaia.pmdec_error < 1.5 and \
            gaia.pmra is not null and gaia.pmdec is not null and gaia.phot_bp_mean_mag is not null and \
            gaia.phot_rp_mean_mag is not null and gaia.phot_g_mean_mag is not null"

# %% [markdown]
# ### Galactic Coordinate System - 'lb'
# local_sphere is preloaded for this example as the query itself takes some time.

# %%
local_sphere = query().archive_pull(sql)
viz(local_sphere).plot('lb')

# %% [markdown]
# ### Equitorial Coordinate System - 'radec'

# %%
viz(test_cluster).plot('radec')

# %% [markdown]
# ### Extrapolated Propermotions - 'movclust'
#
# The moving cluster method is a method used to estimate cluster distance based on stellar kinematics. I find it is useful to visually inspect the proper motions when analysing star cluster data. The same information is contained in a traditional scatter plot. https://community.dur.ac.uk/physics.astrolab/hyades_cp.html

# %%
viz.plot('mov_clust')

# %% [markdown]
# ### Color Magnitude Diagram - 'CMD'

# %%
viz.plot('CMD')
